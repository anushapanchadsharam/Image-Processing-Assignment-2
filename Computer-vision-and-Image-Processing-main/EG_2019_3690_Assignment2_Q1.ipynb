# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Create and display the Original image

# %%
image = np.zeros((150, 150), dtype=np.uint8)
image[30:60, 30:60] = 1
image[70:140, 70:140] = 2


original_image = image
plt.gray()
plt.imshow(original_image)
plt.title("Original Image")
plt.show()

# %% [markdown]
# # Display the Noisy image

# %%
noise = np.random.normal(0, 0.1, image.shape)
noisy_image = image.astype(np.float32) + noise
noisy_image = np.clip(noisy_image, 0, 2).astype(np.uint8)

plt.imshow(noisy_image)
plt.title("Noisy Image")
plt.show()

# %% [markdown]
# # Display the Thresholded image

# %%
threshold_value, thresholded_image = cv2.threshold(noisy_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(thresholded_image)
plt.title("Thresholded Image")
# Out:
# Text(0.5, 1.0, 'Thresholded Image')
